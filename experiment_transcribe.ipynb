# %%
import openwillis as ow
# Out:
# 2025-05-22 23:57:21.239746: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-22 23:57:21.261677: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-05-22 23:57:21.261702: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-05-22 23:57:21.262384: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
filepath = '/net/midgar/work/phuong/fun_workspace/openwillis/sample_data/multi_speaker.wav'

transcript_json, transcript_text = ow.speech_transcription_whisper(filepath = filepath, 
                                                                   model = 'tiny', 
                                                                   compute_type = 'float32', 
                                                                   hf_token = 'my_huggingface_token', 
                                                                   max_speakers = 4, 
                                                                   context = 'panss')
# Out:
# DEBUG:speechbrain.utils.checkpoints:Registered checkpoint save hook for _speechbrain_save
# DEBUG:speechbrain.utils.checkpoints:Registered checkpoint load hook for _speechbrain_load
# DEBUG:speechbrain.utils.checkpoints:Registered checkpoint save hook for save
# DEBUG:speechbrain.utils.checkpoints:Registered checkpoint load hook for load
# INFO:speechbrain.utils.quirks:Applied quirks (see `speechbrain.utils.quirks`): [allow_tf32, disable_jit_profiling]
# INFO:speechbrain.utils.quirks:Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# DEBUG:speechbrain.utils.checkpoints:Registered checkpoint save hook for _save
# DEBUG:speechbrain.utils.checkpoints:Registered checkpoint load hook for _recover
# No language specified, language will be first be detected for each audio file (increases inference time).
# ...

# %%
transcript_json
# Out:
# {'segments': [{'start': 0.071,
#    'end': 2.372,
#    'text': ' It may ask me to sing and then against me.',
#    'words': [{'word': 'It',
#      'start': 0.071,
#      'end': 0.391,
#      'score': 0.637,
#      'speaker': 'speaker1'},
#     {'word': 'may',
#      'start': 0.551,
#      'end': 0.651,
#      'score': 0.265,
#      'speaker': 'speaker1'},
#     {'word': 'ask',
#      'start': 0.711,
#      'end': 0.851,
#      'score': 0.917,
#      'speaker': 'speaker1'},
#     {'word': 'me',
#      'start': 0.891,
#      'end': 0.971,
#      'score': 0.739,
#      'speaker': 'speaker1'},
#     {'word': 'to',
#      'start': 0.991,
#      'end': 1.132,
#      'score': 0.312,
#      'speaker': 'speaker1'},
#     {'word': 'sing',
#      'start': 1.172,
#      'end': 1.332,
#      'score': 0.466,
#      'speaker': 'speaker1'},
#     {'word': 'and',
#      'start': 1.552,
#      'end': 1.712,
#      'score': 0.386,
#      'speaker': 'speaker0'},
#     {'word': 'then',
# ...

# %%
transcript_json_corrected = ow.diarization_correction(transcript_json = transcript_json, 
                                                      model_name = 'bklynhlth/WillisDiarize-v1-quantized', 
                                                      huggingface_token = 'my_huggingface_token',)
# Out:
# INFO:root:Error in Speaker Diarization Correction 'speaker'
